# %%
#### Import required dependencies
import pandas as pd
from prophet import Prophet
import numpy as np
import matplotlib.pyplot as plot
from scipy.stats import linregress

#### Source of dataset
# https://www.kaggle.com/datasets/thedevastator/uncovering-trends-in-health-outcomes-and-socioec/data?select=avg-household-size.csv

# %%
#### Read in the datasets
household_size_data = pd.read_csv("Resources/avg-household-size.csv", index_col='geography')
#household_size_data.info()
household_size_data.head()
# Out:
#                                     index  statefips  countyfips  \
# geography
# Aleutians East Borough, Alaska          0          2          13
# Aleutians West Census Area, Alaska      1          2          16
# Anchorage Municipality, Alaska          2          2          20
# Bethel Census Area, Alaska              3          2          50
# Bristol Bay Borough, Alaska             4          2          60
#
#                                     avghouseholdsize
# geography
# Aleutians East Borough, Alaska                  2.43
# Aleutians West Census Area, Alaska              3.59
# Anchorage Municipality, Alaska                  2.77
# Bethel Census Area, Alaska                      3.86
# Bristol Bay Borough, Alaska                     2.50

# %%
##
cancer_data = pd.read_csv("Resources/cancer_reg.csv", index_col='geography')
#cancer_data.info()
cancer_data.head()
# Out:
#                               index  avganncount  avgdeathsperyear  \
# geography
# Kitsap County, Washington         0       1397.0               469
# Kittitas County, Washington       1        173.0                70
# Klickitat County, Washington      2        102.0                50
# Lewis County, Washington          3        427.0               202
# Lincoln County, Washington        4         57.0                26
#
#                               target_deathrate  incidencerate  medincome  \
# geography
# Kitsap County, Washington                164.9          489.8      61898
# Kittitas County, Washington              161.3          411.6      48127
# Klickitat County, Washington             174.7          349.7      49348
# Lewis County, Washington                 194.8          430.4      44243
# Lincoln County, Washington               144.4          350.1      49955
#
#                               popest2015  povertypercent  studypercap  \
# geography
# Kitsap County, Washington         260131            11.2   499.748204
# Kittitas County, Washington        43269            18.6    23.111234
# Klickitat County, Washington       21026            14.6    47.560164
# Lewis County, Washington           75882            17.1   342.637253
# Lincoln County, Washington         10321            12.5     0.000000
#
#                                        binnedinc  ...  \
# geography                                         ...
# Kitsap County, Washington      (61494.5, 125635]  ...
# Kittitas County, Washington   (48021.6, 51046.4]  ...
# Klickitat County, Washington  (48021.6, 51046.4]  ...
# Lewis County, Washington        (42724.4, 45201]  ...
# Lincoln County, Washington    (48021.6, 51046.4]  ...
#
#                               pctprivatecoveragealone  pctempprivcoverage  \
# geography
# Kitsap County, Washington                         NaN                41.6
# Kittitas County, Washington                      53.8                43.6
# Klickitat County, Washington                     43.5                34.9
# Lewis County, Washington                         40.3                35.0
# Lincoln County, Washington                       43.9                35.1
#
#                               pctpubliccoverage  pctpubliccoveragealone  \
# geography
# Kitsap County, Washington                  32.9                    14.0
# Kittitas County, Washington                31.1                    15.3
# Klickitat County, Washington               42.1                    21.1
# Lewis County, Washington                   45.3                    25.0
# Lincoln County, Washington                 44.0                    22.7
#
#                                pctwhite  pctblack  pctasian  pctotherrace  \
# geography
# Kitsap County, Washington     81.780529  2.594728  4.821857      1.843479
# Kittitas County, Washington   89.228509  0.969102  2.246233      3.741352
# Klickitat County, Washington  90.922190  0.739673  0.465898      2.747358
# Lewis County, Washington      91.744686  0.782626  1.161359      1.362643
# Lincoln County, Washington    94.104024  0.270192  0.665830      0.492135
#
#                               pctmarriedhouseholds  birthrate
# geography
# Kitsap County, Washington                52.856076   6.118831
# Kittitas County, Washington              45.372500   4.333096
# Klickitat County, Washington             54.444868   3.729488
# Lewis County, Washington                 51.021514   4.603841
# Lincoln County, Washington               54.027460   6.796657
#
# [5 rows x 33 columns]

# %%
#### Combine the dataframes on geo
combined_data = pd.merge(household_size_data, cancer_data, on="geography", how="outer")
combined_data.info()
combined_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3220 entries, Aleutians East Borough, Alaska to Weston County, Wyoming
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index_x                  3220 non-null   int64
#  1   statefips                3220 non-null   int64
#  2   countyfips               3220 non-null   int64
#  3   avghouseholdsize         3220 non-null   float64
#  4   index_y                  3047 non-null   float64
#  5   avganncount              3047 non-null   float64
#  6   avgdeathsperyear         3047 non-null   float64
#  7   target_deathrate         3047 non-null   float64
#  8   incidencerate            3047 non-null   float64
#  9   medincome                3047 non-null   float64
#  10  popest2015               3047 non-null   float64
#  11  povertypercent           3047 non-null   float64
#  12  studypercap              3047 non-null   float64
#  13  binnedinc                3047 non-null   object
#  14  medianage                3047 non-null   float64
#  15  medianagemale            3047 non-null   float64
#  16  medianagefemale          3047 non-null   float64
#  17  percentmarried           3047 non-null   float64
#  18  pctnohs18_24             3047 non-null   float64
#  19  pcths18_24               3047 non-null   float64
#  20  pctsomecol18_24          762 non-null    float64
#  21  pctbachdeg18_24          3047 non-null   float64
#  22  pcths25_over             3047 non-null   float64
#  23  pctbachdeg25_over        3047 non-null   float64
#  24  pctemployed16_over       2895 non-null   float64
#  25  pctunemployed16_over     3047 non-null   float64
#  26  pctprivatecoverage       3047 non-null   float64
#  27  pctprivatecoveragealone  2438 non-null   float64
#  28  pctempprivcoverage       3047 non-null   float64
#  29  pctpubliccoverage        3047 non-null   float64
#  30  pctpubliccoveragealone   3047 non-null   float64
#  31  pctwhite                 3047 non-null   float64
#  32  pctblack                 3047 non-null   float64
#  33  pctasian                 3047 non-null   float64
#  34  pctotherrace             3047 non-null   float64
#  35  pctmarriedhouseholds     3047 non-null   float64
#  36  birthrate                3047 non-null   float64
# dtypes: float64(33), int64(3), object(1)
# memory usage: 955.9+ KB
#                                     index_x  statefips  countyfips  \
# geography
# Aleutians East Borough, Alaska            0          2          13
# Aleutians West Census Area, Alaska        1          2          16
# Anchorage Municipality, Alaska            2          2          20
# Bethel Census Area, Alaska                3          2          50
# Bristol Bay Borough, Alaska               4          2          60
#
#                                     avghouseholdsize  index_y  avganncount  \
# geography
# Aleutians East Borough, Alaska                  2.43      NaN          NaN
# Aleutians West Census Area, Alaska              3.59   2713.0          8.0
# Anchorage Municipality, Alaska                  2.77   2714.0       1085.0
# Bethel Census Area, Alaska                      3.86   2715.0         37.0
# Bristol Bay Borough, Alaska                     2.50      NaN          NaN
#
#                                     avgdeathsperyear  target_deathrate  \
# geography
# Aleutians East Borough, Alaska                   NaN               NaN
# Aleutians West Census Area, Alaska               3.0             203.3
# Anchorage Municipality, Alaska                 352.0             167.5
# Bethel Census Area, Alaska                      20.0             218.8
# Bristol Bay Borough, Alaska                      NaN               NaN
#
#                                     incidencerate  medincome  ...  \
# geography                                                     ...
# Aleutians East Borough, Alaska                NaN        NaN  ...
# Aleutians West Census Area, Alaska          201.3    68387.0  ...
# Anchorage Municipality, Alaska              453.3    75200.0  ...
# Bethel Census Area, Alaska                  338.2    45808.0  ...
# Bristol Bay Borough, Alaska                   NaN        NaN  ...
#
#                                     pctprivatecoveragealone  \
# geography
# Aleutians East Borough, Alaska                          NaN
# Aleutians West Census Area, Alaska                     60.4
# Anchorage Municipality, Alaska                          NaN
# Bethel Census Area, Alaska                             25.8
# Bristol Bay Borough, Alaska                             NaN
#
#                                     pctempprivcoverage  pctpubliccoverage  \
# geography
# Aleutians East Borough, Alaska                     NaN                NaN
# Aleutians West Census Area, Alaska                58.3               11.2
# Anchorage Municipality, Alaska                    45.9               24.5
# Bethel Census Area, Alaska                        25.1               47.3
# Bristol Bay Borough, Alaska                        NaN                NaN
#
#                                    pctpubliccoveragealone   pctwhite  \
# geography
# Aleutians East Borough, Alaska                        NaN        NaN
# Aleutians West Census Area, Alaska                    6.2  31.562280
# Anchorage Municipality, Alaska                       12.9  64.944652
# Bethel Census Area, Alaska                           36.1  12.016202
# Bristol Bay Borough, Alaska                           NaN        NaN
#
#                                     pctblack   pctasian  pctotherrace  \
# geography
# Aleutians East Borough, Alaska           NaN        NaN           NaN
# Aleutians West Census Area, Alaska  4.732583  37.156932      5.295567
# Anchorage Municipality, Alaska      5.854427   8.800530      1.747201
# Bethel Census Area, Alaska          0.798830   1.175743      0.343159
# Bristol Bay Borough, Alaska              NaN        NaN           NaN
#
#                                     pctmarriedhouseholds  birthrate
# geography
# Aleutians East Borough, Alaska                       NaN        NaN
# Aleutians West Census Area, Alaska             42.882250   4.391052
# Anchorage Municipality, Alaska                 48.361303   5.994294
# Bethel Census Area, Alaska                     45.521390   9.156280
# Bristol Bay Borough, Alaska                          NaN        NaN
#
# [5 rows x 37 columns]

# %%
#### Description of columns
# statefips: State identification number. (Integer)
# countyfips: County identification number. (Integer)
# avghouseholdsize: Average size of households in the county. (Float)
# geography: Location name. (String)
# geography: Location name. (String)
# avganncount: Average annual count of cancer cases in the county. (Numeric)
# avgdeathsperyear: Average number of deaths per year in the county. (Numeric)
# target_deathrate: Number of deaths per 100k individuals in each county. (Numeric)
# medincome: Median household income for the county. (Numeric)
# popest2015: Population estimates for 2015. (Numeric)
# povertypercent: Percentage of people living in poverty. (Numeric)
# studypercap: Number of clinical trials per capita in the given county. (Numeric)
# binnedinc: Binned income for each county. (Categorical)
# medianage: Median age of the population in the county. (Numeric)
# medianagemale: Median age of the male population in the county. (Numeric)
# medianagefemale: Median age of the female population in the county. (Numeric)
# percentmarried: Percentage of people who are married in the county. (Numeric)
# pctnohs18_24: Percentage of people aged 18-24 who did not graduate high school. (Numeric)
# pcths18_24: Percentage of people aged 18-24 who graduated high school. (Numeric)
# pctsomecol18_24: Percentage of people aged 18-24 who attended some college. (Numeric)
# pctbachdeg18_24: Percentage of people aged 18-24 who have a bachelor's degree. (Numeric)
# pcths25_over: Percentage of people aged 25 and over who graduated high school. (Numeric)
# pctbachdeg25_over: Percentage of people aged 25 and over who have a bachelor's degree. (Numeric)
# pctemployed16_over: Percentage of people aged 16 and over who are employed. (Numeric)
# pctunemployed16_over: Percentage of people aged 16 and over who are unemployed. (Numeric)
# pctprivatecoverage: Percentage of people with private health insuranc

#### Drop the NA values
combined_data = combined_data.dropna()
combined_data.info()

#### Retain only data we are interested in
#focused_data = combined_data.drop(columns=['index_x', 'index_y', 'medincome', 'povertypercent', 'binnedinc', 'percentmarried',
#                                            'pctnohs18_24', 'pcths18_24', 'pctsomecol18_24', 'pctbachdeg18_24', 'pcths25_over',
#                                           'pctbachdeg25_over', 'pctemployed16_over', 'pctunemployed16_over', 'pctprivatecoverage',
#                                           'pctprivatecoveragealone', 'pctempprivcoverage', 'pctpubliccoverage', 'pctpubliccoveragealone',
#                                            'pctwhite', 'pctblack', 'pctasian', 'pctotherrace', 'pctmarriedhouseholds', 'birthrate'])

# Better way to do this -> transfer the columns that you do want to a new df
focused_data = combined_data[['avganncount', 'popest2015', 'studypercap', 'medianage', 'medianagemale', 'medianagefemale', 'target_deathrate']]

focused_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, Haines Borough, Alaska to Sheridan County, Wyoming
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index_x                  591 non-null    int64
#  1   statefips                591 non-null    int64
#  2   countyfips               591 non-null    int64
#  3   avghouseholdsize         591 non-null    float64
#  4   index_y                  591 non-null    float64
#  5   avganncount              591 non-null    float64
#  6   avgdeathsperyear         591 non-null    float64
#  7   target_deathrate         591 non-null    float64
#  8   incidencerate            591 non-null    float64
#  9   medincome                591 non-null    float64
#  10  popest2015               591 non-null    float64
#  11  povertypercent           591 non-null    float64
#  12  studypercap              591 non-null    float64
#  13  binnedinc                591 non-null    object
#  14  medianage                591 non-null    float64
#  15  medianagemale            591 non-null    float64
#  16  medianagefemale          591 non-null    float64
#  17  percentmarried           591 non-null    float64
#  18  pctnohs18_24             591 non-null    float64
#  19  pcths18_24               591 non-null    float64
#  20  pctsomecol18_24          591 non-null    float64
#  21  pctbachdeg18_24          591 non-null    float64
#  22  pcths25_over             591 non-null    float64
#  23  pctbachdeg25_over        591 non-null    float64
#  24  pctemployed16_over       591 non-null    float64
#  25  pctunemployed16_over     591 non-null    float64
#  26  pctprivatecoverage       591 non-null    float64
#  27  pctprivatecoveragealone  591 non-null    float64
#  28  pctempprivcoverage       591 non-null    float64
#  29  pctpubliccoverage        591 non-null    float64
#  30  pctpubliccoveragealone   591 non-null    float64
#  31  pctwhite                 591 non-null    float64
#  32  pctblack                 591 non-null    float64
#  33  pctasian                 591 non-null    float64
#  34  pctotherrace             591 non-null    float64
#  35  pctmarriedhouseholds     591 non-null    float64
#  36  birthrate                591 non-null    float64
# dtypes: float64(33), int64(3), object(1)
# memory usage: 175.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, Haines Borough, Alaska to Sheridan County, Wyoming
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   avganncount       591 non-null    float64
#  1   popest2015        591 non-null    float64
#  2   studypercap       591 non-null    float64
#  3   medianage         591 non-null    float64
#  4   medianagemale     591 non-null    float64
#  5   medianagefemale   591 non-null    float64
#  6   target_deathrate  591 non-null    float64
# dtypes: float64(7)
# memory usage: 36.9+ KB

# %%
focused_data
# Out:
#                                    avganncount  popest2015  studypercap  \
# geography
# Haines Borough, Alaska                    13.0      2534.0     0.000000
# Kenai Peninsula Borough, Alaska          266.0     58059.0     0.000000
# Ketchikan Gateway Borough, Alaska         63.0     13709.0     0.000000
# Yukon-Koyukuk Census Area, Alaska         27.0      5533.0     0.000000
# Cherokee County, Alabama                 158.0     25859.0     0.000000
# ...                                        ...         ...          ...
# Putnam County, West Virginia             328.0     56848.0   211.089220
# Webster County, West Virginia             65.0      8755.0   114.220445
# Hot Springs County, Wyoming               37.0      4741.0     0.000000
# Park County, Wyoming                     158.0     29228.0  1402.764472
# Sheridan County, Wyoming                 173.0     30009.0  1499.550135
#
#                                    medianage  medianagemale  medianagefemale  \
# geography
# Haines Borough, Alaska                  45.5           45.6             45.3
# Kenai Peninsula Borough, Alaska         40.5           40.0             41.1
# Ketchikan Gateway Borough, Alaska       38.7           37.9             39.4
# Yukon-Koyukuk Census Area, Alaska       35.0           35.4             34.0
# Cherokee County, Alabama                45.4           44.6             46.2
# ...                                      ...            ...              ...
# Putnam County, West Virginia            41.0           40.4             41.6
# Webster County, West Virginia           46.3           45.5             46.6
# Hot Springs County, Wyoming             49.6           48.1             50.1
# Park County, Wyoming                    43.6           42.3             44.6
# Sheridan County, Wyoming                42.2           42.0             42.5
#
#                                    target_deathrate
# geography
# Haines Borough, Alaska                        126.3
# Kenai Peninsula Borough, Alaska               168.1
# Ketchikan Gateway Borough, Alaska             205.0
# Yukon-Koyukuk Census Area, Alaska             206.6
# Cherokee County, Alabama                      191.2
# ...                                             ...
# Putnam County, West Virginia                  171.5
# Webster County, West Virginia                 259.5
# Hot Springs County, Wyoming                   163.0
# Park County, Wyoming                          152.0
# Sheridan County, Wyoming                      168.7
#
# [591 rows x 7 columns]

# %%
#### Define a function to remove outliers
def get_outlier_bounds(input):
    Q1 = input.quantile(0.25)
    Q3 = input.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return [lower_bound, upper_bound]

# %%
#### Remove outliers from all relevant columns
focused_data_clean = focused_data
cols = ['avganncount', 'popest2015', 'medianage', 'medianagemale', 'medianagefemale', 'target_deathrate']

for x in cols:
    bounds = get_outlier_bounds(focused_data_clean[x])
    focused_data_clean = focused_data_clean[(focused_data_clean[x] >= bounds[0]) & (focused_data_clean[x] <= bounds[1])]

focused_data_clean
# Out:
#                                    avganncount  popest2015  studypercap  \
# geography
# Haines Borough, Alaska                    13.0      2534.0     0.000000
# Kenai Peninsula Borough, Alaska          266.0     58059.0     0.000000
# Ketchikan Gateway Borough, Alaska         63.0     13709.0     0.000000
# Yukon-Koyukuk Census Area, Alaska         27.0      5533.0     0.000000
# Cherokee County, Alabama                 158.0     25859.0     0.000000
# ...                                        ...         ...          ...
# Preston County, West Virginia            183.0     33940.0     0.000000
# Putnam County, West Virginia             328.0     56848.0   211.089220
# Hot Springs County, Wyoming               37.0      4741.0     0.000000
# Park County, Wyoming                     158.0     29228.0  1402.764472
# Sheridan County, Wyoming                 173.0     30009.0  1499.550135
#
#                                    medianage  medianagemale  medianagefemale  \
# geography
# Haines Borough, Alaska                  45.5           45.6             45.3
# Kenai Peninsula Borough, Alaska         40.5           40.0             41.1
# Ketchikan Gateway Borough, Alaska       38.7           37.9             39.4
# Yukon-Koyukuk Census Area, Alaska       35.0           35.4             34.0
# Cherokee County, Alabama                45.4           44.6             46.2
# ...                                      ...            ...              ...
# Preston County, West Virginia           42.3           40.4             43.5
# Putnam County, West Virginia            41.0           40.4             41.6
# Hot Springs County, Wyoming             49.6           48.1             50.1
# Park County, Wyoming                    43.6           42.3             44.6
# Sheridan County, Wyoming                42.2           42.0             42.5
#
#                                    target_deathrate
# geography
# Haines Borough, Alaska                        126.3
# Kenai Peninsula Borough, Alaska               168.1
# Ketchikan Gateway Borough, Alaska             205.0
# Yukon-Koyukuk Census Area, Alaska             206.6
# Cherokee County, Alabama                      191.2
# ...                                             ...
# Preston County, West Virginia                 169.8
# Putnam County, West Virginia                  171.5
# Hot Springs County, Wyoming                   163.0
# Park County, Wyoming                          152.0
# Sheridan County, Wyoming                      168.7
#
# [354 rows x 7 columns]

# %%
#### Check and clean the important data
#focused_data['medianage'].describe()
#focused_data['medianagemale'].describe()
#focused_data['medianagefemale'].describe()

#### Remove outliers from median age
#Q1 = focused_data['medianage'].quantile(0.25)
#Q3 = focused_data['medianage'].quantile(0.75)
#IQR = Q3 - Q1
#lower_bound = Q1 - 1.5 * IQR
#upper_bound = Q3 + 1.5 * IQR

# Step 4: Filter out the outliers
#focused_data_clean = focused_data[(focused_data['medianage'] >= lower_bound) & (focused_data['medianage'] <= upper_bound)]
#focused_data_clean
#focused_data_clean['medianage'].describe()

#### Requires additional filtering
# remove and rows where median age > 90
#above90 = 90
#focused_data_clean = focused_data_clean[(focused_data['medianage'] <= above90)]
#focused_data_clean = focused_data_clean[(focused_data['medianagemale'] <= above90)]
#focused_data_clean = focused_data_clean[(focused_data['medianagefemale'] <= above90)]
#focused_data_clean['medianagemale'].describe()
# Out:
# C:\Users\jsk33\AppData\Local\Temp\ipykernel_25332\3186303462.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   focused_data_clean = focused_data_clean[(focused_data['medianage'] <= above90)]
# C:\Users\jsk33\AppData\Local\Temp\ipykernel_25332\3186303462.py:24: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   focused_data_clean = focused_data_clean[(focused_data['medianagemale'] <= above90)]
# C:\Users\jsk33\AppData\Local\Temp\ipykernel_25332\3186303462.py:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   focused_data_clean = focused_data_clean[(focused_data['medianagefemale'] <= above90)]
# count    557.000000
# mean      39.578995
# std        4.363609
# min       23.700000
# 25%       36.800000
# 50%       39.500000
# 75%       42.100000
# max       53.100000
# Name: medianagemale, dtype: float64

# %%
#### Incidence it total counts. Need to calculate per capita
focused_data_clean['incidence'] = (focused_data_clean['avganncount'] / focused_data_clean['popest2015'])*100
focused_data_clean['incidence'].describe()
#focused_data_clean
# Out:
# count    557.000000
# mean       3.285133
# std       14.375185
# min        0.260234
# 25%        0.488179
# 50%        0.560103
# 75%        0.642438
# max      236.751228
# Name: incidence, dtype: float64

# %%
focused_data_clean['avganncount'].describe()
# Out:
# count      557.000000
# mean       701.645805
# std       2031.596071
# min          6.000000
# 25%         91.000000
# 50%        183.000000
# 75%        550.000000
# max      38150.000000
# Name: avganncount, dtype: float64

# %%
focused_data_clean['popest2015'].describe()
# Out:
# count    5.570000e+02
# mean     1.179936e+05
# std      5.190826e+05
# min      8.290000e+02
# 25%      1.253100e+04
# 50%      2.745100e+04
# 75%      6.353100e+04
# max      1.017029e+07
# Name: popest2015, dtype: float64

# %%
#### Check the correlations between current columns of interest
# focused_data.corr()
focused_data_clean[['incidence', 'medianage', 'medianagemale', 'medianagefemale', 'target_deathrate']].corr()
# Out:
#                   incidence  medianage  medianagemale  medianagefemale  \
# incidence          1.000000   0.169456       0.152264         0.178183
# medianage          0.169456   1.000000       0.975817         0.969640
# medianagemale      0.152264   0.975817       1.000000         0.903703
# medianagefemale    0.178183   0.969640       0.903703         1.000000
# target_deathrate   0.058587   0.051621       0.025257         0.069053
#
#                   target_deathrate
# incidence                 0.058587
# medianage                 0.051621
# medianagemale             0.025257
# medianagefemale           0.069053
# target_deathrate          1.000000

# %%
plot.scatter(focused_data_clean['medianage'], focused_data_clean['incidence'], marker="o", facecolors="blue", edgecolors="black")
plot.figure(figsize=(200, 10))
plot.show()

# %%
#### Make a three panel plot of incidence against ages

# Create a figure and three subplots (panels)
fig, axs = plot.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# First panel - Line plot
axs[0].scatter(focused_data_clean['medianage'], focused_data_clean['incidence'], marker="o", facecolors="blue", edgecolors="black")
#axs[0].set_title('Sine Function')
#axs[0].set_xlabel('x')
#axs[0].set_ylabel('sin(x)')
#axs[0].legend()

# First panel - Line plot
axs[1].scatter(focused_data_clean['medianagemale'], focused_data_clean['incidence'], marker="o", facecolors="blue", edgecolors="black")
#axs[0].set_title('Sine Function')
#axs[0].set_xlabel('x')
#axs[0].set_ylabel('sin(x)')
#axs[0].legend()

# First panel - Line plot
axs[2].scatter(focused_data_clean['medianagefemale'], focused_data_clean['incidence'], marker="o", facecolors="blue", edgecolors="black")
#axs[0].set_title('Sine Function')
#axs[0].set_xlabel('x')
#axs[0].set_ylabel('sin(x)')
#axs[0].legend()


# Adjust layout
plot.tight_layout()

# Show the plot
plot.show()
