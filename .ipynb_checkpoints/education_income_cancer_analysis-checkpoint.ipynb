# %%
# Kala Project 1 Notebook
# Analyzing relationships between cancer rates and death rates AND education and income across all states and counties in the US

# %%
# Dependencies
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
# Read the avg-household-size data into a DataFrame
df_household_size = pd.read_csv("Resources/avg-household-size.csv")
df_household_size.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             3220 non-null   int64
#  1   statefips         3220 non-null   int64
#  2   countyfips        3220 non-null   int64
#  3   avghouseholdsize  3220 non-null   float64
#  4   geography         3220 non-null   object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 125.9+ KB

# %%
# Clean the df, index column is not needed, added new state column for grouping
df_household_size = df_household_size.drop(columns='index')
df_household_size["state"] = df_household_size["geography"].str.split(", ").str.get(1)
df_household_size = df_household_size.set_index('geography')
df_household_size
# Out:
#                                     statefips  countyfips  avghouseholdsize  \
# geography
# Aleutians East Borough, Alaska              2          13              2.43
# Aleutians West Census Area, Alaska          2          16              3.59
# Anchorage Municipality, Alaska              2          20              2.77
# Bethel Census Area, Alaska                  2          50              3.86
# Bristol Bay Borough, Alaska                 2          60              2.50
# ...                                       ...         ...               ...
# Sweetwater County, Wyoming                 56          37              2.64
# Teton County, Wyoming                      56          39              2.63
# Uinta County, Wyoming                      56          41              2.76
# Washakie County, Wyoming                   56          43              2.34
# Weston County, Wyoming                     56          45              2.27
#
#                                       state
# geography
# Aleutians East Borough, Alaska       Alaska
# Aleutians West Census Area, Alaska   Alaska
# Anchorage Municipality, Alaska       Alaska
# Bethel Census Area, Alaska           Alaska
# Bristol Bay Borough, Alaska          Alaska
# ...                                     ...
# Sweetwater County, Wyoming          Wyoming
# Teton County, Wyoming               Wyoming
# Uinta County, Wyoming               Wyoming
# Washakie County, Wyoming            Wyoming
# Weston County, Wyoming              Wyoming
#
# [3220 rows x 4 columns]

# %%
# Read the cancer data into a DataFrame
df_cancer = pd.read_csv("Resources/cancer_reg.csv",
    index_col='geography')
df_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3047 entries, Kitsap County, Washington to Geary County, Kansas
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    3047 non-null   int64
#  1   avganncount              3047 non-null   float64
#  2   avgdeathsperyear         3047 non-null   int64
#  3   target_deathrate         3047 non-null   float64
#  4   incidencerate            3047 non-null   float64
#  5   medincome                3047 non-null   int64
#  6   popest2015               3047 non-null   int64
#  7   povertypercent           3047 non-null   float64
#  8   studypercap              3047 non-null   float64
#  9   binnedinc                3047 non-null   object
#  10  medianage                3047 non-null   float64
#  11  medianagemale            3047 non-null   float64
#  12  medianagefemale          3047 non-null   float64
#  13  percentmarried           3047 non-null   float64
#  14  pctnohs18_24             3047 non-null   float64
#  15  pcths18_24               3047 non-null   float64
#  16  pctsomecol18_24          762 non-null    float64
#  17  pctbachdeg18_24          3047 non-null   float64
#  18  pcths25_over             3047 non-null   float64
#  19  pctbachdeg25_over        3047 non-null   float64
#  20  pctemployed16_over       2895 non-null   float64
#  21  pctunemployed16_over     3047 non-null   float64
#  22  pctprivatecoverage       3047 non-null   float64
#  23  pctprivatecoveragealone  2438 non-null   float64
#  24  pctempprivcoverage       3047 non-null   float64
#  25  pctpubliccoverage        3047 non-null   float64
#  26  pctpubliccoveragealone   3047 non-null   float64
#  27  pctwhite                 3047 non-null   float64
#  28  pctblack                 3047 non-null   float64
#  29  pctasian                 3047 non-null   float64
#  30  pctotherrace             3047 non-null   float64
#  31  pctmarriedhouseholds     3047 non-null   float64
#  32  birthrate                3047 non-null   float64
# dtypes: float64(28), int64(4), object(1)
# memory usage: 809.4+ KB

# %%
#Display the second df
df_cancer = df_cancer.drop(columns='index')
df_cancer
# Out:
#                               avganncount  avgdeathsperyear  target_deathrate  \
# geography
# Kitsap County, Washington     1397.000000               469             164.9
# Kittitas County, Washington    173.000000                70             161.3
# Klickitat County, Washington   102.000000                50             174.7
# Lewis County, Washington       427.000000               202             194.8
# Lincoln County, Washington      57.000000                26             144.4
# ...                                   ...               ...               ...
# Ellsworth County, Kansas      1962.667684                15             149.6
# Finney County, Kansas         1962.667684                43             150.1
# Ford County, Kansas           1962.667684                46             153.9
# Franklin County, Kansas       1962.667684                52             175.0
# Geary County, Kansas          1962.667684                48             213.6
#
#                               incidencerate  medincome  popest2015  \
# geography
# Kitsap County, Washington        489.800000      61898      260131
# Kittitas County, Washington      411.600000      48127       43269
# Klickitat County, Washington     349.700000      49348       21026
# Lewis County, Washington         430.400000      44243       75882
# Lincoln County, Washington       350.100000      49955       10321
# ...                                     ...        ...         ...
# Ellsworth County, Kansas         453.549422      46961        6343
# Finney County, Kansas            453.549422      48609       37118
# Ford County, Kansas              453.549422      51144       34536
# Franklin County, Kansas          453.549422      50745       25609
# Geary County, Kansas             453.549422      41193       37030
#
#                               povertypercent  studypercap           binnedinc  \
# geography
# Kitsap County, Washington               11.2   499.748204   (61494.5, 125635]
# Kittitas County, Washington             18.6    23.111234  (48021.6, 51046.4]
# Klickitat County, Washington            14.6    47.560164  (48021.6, 51046.4]
# Lewis County, Washington                17.1   342.637253    (42724.4, 45201]
# Lincoln County, Washington              12.5     0.000000  (48021.6, 51046.4]
# ...                                      ...          ...                 ...
# Ellsworth County, Kansas                12.4     0.000000    (45201, 48021.6]
# Finney County, Kansas                   18.8   377.175494  (48021.6, 51046.4]
# Ford County, Kansas                     15.0  1968.959926  (51046.4, 54545.6]
# Franklin County, Kansas                 13.3     0.000000  (48021.6, 51046.4]
# Geary County, Kansas                    13.9     0.000000  (40362.7, 42724.4]
#
#                               medianage  ...  pctprivatecoveragealone  \
# geography                                ...
# Kitsap County, Washington          39.3  ...                      NaN
# Kittitas County, Washington        33.0  ...                     53.8
# Klickitat County, Washington       45.0  ...                     43.5
# Lewis County, Washington           42.8  ...                     40.3
# Lincoln County, Washington         48.3  ...                     43.9
# ...                                 ...  ...                      ...
# Ellsworth County, Kansas           44.2  ...                     54.9
# Finney County, Kansas              30.4  ...                     53.3
# Ford County, Kansas                30.9  ...                     52.6
# Franklin County, Kansas            39.0  ...                     56.3
# Geary County, Kansas               26.2  ...                     60.3
#
#                               pctempprivcoverage  pctpubliccoverage  \
# geography
# Kitsap County, Washington                   41.6               32.9
# Kittitas County, Washington                 43.6               31.1
# Klickitat County, Washington                34.9               42.1
# Lewis County, Washington                    35.0               45.3
# Lincoln County, Washington                  35.1               44.0
# ...                                          ...                ...
# Ellsworth County, Kansas                    44.6               31.7
# Finney County, Kansas                       48.6               28.8
# Ford County, Kansas                         47.8               26.6
# Franklin County, Kansas                     49.6               29.5
# Geary County, Kansas                        22.9               25.1
#
#                               pctpubliccoveragealone   pctwhite   pctblack  \
# geography
# Kitsap County, Washington                       14.0  81.780529   2.594728
# Kittitas County, Washington                     15.3  89.228509   0.969102
# Klickitat County, Washington                    21.1  90.922190   0.739673
# Lewis County, Washington                        25.0  91.744686   0.782626
# Lincoln County, Washington                      22.7  94.104024   0.270192
# ...                                              ...        ...        ...
# Ellsworth County, Kansas                        13.2  90.280811   3.837754
# Finney County, Kansas                           17.7  75.706245   2.326771
# Ford County, Kansas                             16.8  87.961629   2.313188
# Franklin County, Kansas                         14.0  92.905681   1.176562
# Geary County, Kansas                            12.6  70.098132  16.590100
#
#                               pctasian  pctotherrace  pctmarriedhouseholds  \
# geography
# Kitsap County, Washington     4.821857      1.843479             52.856076
# Kittitas County, Washington   2.246233      3.741352             45.372500
# Klickitat County, Washington  0.465898      2.747358             54.444868
# Lewis County, Washington      1.161359      1.362643             51.021514
# Lincoln County, Washington    0.665830      0.492135             54.027460
# ...                                ...           ...                   ...
# Ellsworth County, Kansas      0.327613      1.700468             51.063830
# Finney County, Kansas         4.044920     14.130288             52.007937
# Ford County, Kansas           1.316472      5.680705             55.153949
# Franklin County, Kansas       0.244632      2.131790             58.484232
# Geary County, Kansas          3.177753      1.356457             56.040242
#
#                               birthrate
# geography
# Kitsap County, Washington      6.118831
# Kittitas County, Washington    4.333096
# Klickitat County, Washington   3.729488
# Lewis County, Washington       4.603841
# Lincoln County, Washington     6.796657
# ...                                 ...
# Ellsworth County, Kansas       7.773512
# Finney County, Kansas          8.186470
# Ford County, Kansas            7.809192
# Franklin County, Kansas        7.582938
# Geary County, Kansas           8.981723
#
# [3047 rows x 32 columns]

# %%
df_combined = pd.merge(df_household_size, df_cancer, on="geography", how="outer")
df_combined = df_combined.loc[df_combined['avganncount'] != 1962.668]
df_combined['actdeathrate'] = (df_combined['avgdeathsperyear'] * 100000) / df_combined['popest2015']
df_combined['actincidencerate'] = (df_combined['avganncount'] * 100000) / df_combined['popest2015']

# %%
df_combined = df_combined.dropna()

# %%
df_combined[['popest2015', 'avganncount', 'avgdeathsperyear', 'actincidencerate', 'actdeathrate', 'avghouseholdsize']].corr()
# Out:
#                   popest2015  avganncount  avgdeathsperyear  actincidencerate  \
# popest2015          1.000000     0.957520          0.988023         -0.042474
# avganncount         0.957520     1.000000          0.963882          0.121902
# avgdeathsperyear    0.988023     0.963882          1.000000         -0.050832
# actincidencerate   -0.042474     0.121902         -0.050832          1.000000
# actdeathrate       -0.208970    -0.162996         -0.193882          0.274760
# avghouseholdsize    0.190718     0.141732          0.178358         -0.166598
#
#                   actdeathrate  avghouseholdsize
# popest2015           -0.208970          0.190718
# avganncount          -0.162996          0.141732
# avgdeathsperyear     -0.193882          0.178358
# actincidencerate      0.274760         -0.166598
# actdeathrate          1.000000         -0.569896
# avghouseholdsize     -0.569896          1.000000

# %%
plt.scatter(df_combined['avghouseholdsize'], df_combined['actincidencerate'], marker="o", facecolors="blue", edgecolors="black")
plt.show()

# %%
plt.scatter(df_combined['popest2015'], df_combined['avgdeathsperyear'], marker="o", facecolors="pink", edgecolors="black")
plt.figure(figsize=(200, 10))
plt.show()

# %%
plt.scatter(df_combined['popest2015'], df_combined['actincidencerate'], marker="o", facecolors="yellow", edgecolors="black")
plt.show()

# %%
my_educ_cols = ['pcths18_24', 'pctnohs18_24', 'pctsomecol18_24', 'pctbachdeg18_24', 'pcths25_over', 'pctbachdeg25_over']
my_income_cols = ['medincome', 'povertypercent']
my_empl_cols = ['pctemployed16_over', 'pctunemployed16_over']
my_master_cols = ['popest2015', 'avganncount', 'avgdeathsperyear', 'actincidencerate', 'actdeathrate']
df_combined[my_master_cols + my_income_cols].corr()
# Out:
#                   popest2015  avganncount  avgdeathsperyear  actincidencerate  \
# popest2015          1.000000     0.957520          0.988023         -0.042474
# avganncount         0.957520     1.000000          0.963882          0.121902
# avgdeathsperyear    0.988023     0.963882          1.000000         -0.050832
# actincidencerate   -0.042474     0.121902         -0.050832          1.000000
# actdeathrate       -0.208970    -0.162996         -0.193882          0.274760
# medincome           0.177701     0.219067          0.189414          0.018181
# povertypercent     -0.039724    -0.105566         -0.048667         -0.117969
#
#                   actdeathrate  medincome  povertypercent
# popest2015           -0.208970   0.177701       -0.039724
# avganncount          -0.162996   0.219067       -0.105566
# avgdeathsperyear     -0.193882   0.189414       -0.048667
# actincidencerate      0.274760   0.018181       -0.117969
# actdeathrate          1.000000  -0.461109        0.153909
# medincome            -0.461109   1.000000       -0.796091
# povertypercent        0.153909  -0.796091        1.000000

# %%
df_combined[my_master_cols + my_empl_cols].corr()
# Out:
#                       popest2015  avganncount  avgdeathsperyear  \
# popest2015              1.000000     0.957520          0.988023
# avganncount             0.957520     1.000000          0.963882
# avgdeathsperyear        0.988023     0.963882          1.000000
# actincidencerate       -0.042474     0.121902         -0.050832
# actdeathrate           -0.208970    -0.162996         -0.193882
# pctemployed16_over      0.115205     0.177038          0.116513
# pctunemployed16_over    0.048669    -0.000131          0.061478
#
#                       actincidencerate  actdeathrate  pctemployed16_over  \
# popest2015                   -0.042474     -0.208970            0.115205
# avganncount                   0.121902     -0.162996            0.177038
# avgdeathsperyear             -0.050832     -0.193882            0.116513
# actincidencerate              1.000000      0.274760            0.075935
# actdeathrate                  0.274760      1.000000           -0.331886
# pctemployed16_over            0.075935     -0.331886            1.000000
# pctunemployed16_over         -0.090964      0.055119           -0.669580
#
#                       pctunemployed16_over
# popest2015                        0.048669
# avganncount                      -0.000131
# avgdeathsperyear                  0.061478
# actincidencerate                 -0.090964
# actdeathrate                      0.055119
# pctemployed16_over               -0.669580
# pctunemployed16_over              1.000000

# %%
# Is there a relationship between cancer incidence and death rates
# and educational level?
df_combined[my_master_cols + my_educ_cols].corr()
# Out:
#                    popest2015  avganncount  avgdeathsperyear  \
# popest2015           1.000000     0.957520          0.988023
# avganncount          0.957520     1.000000          0.963882
# avgdeathsperyear     0.988023     0.963882          1.000000
# actincidencerate    -0.042474     0.121902         -0.050832
# actdeathrate        -0.208970    -0.162996         -0.193882
# pcths18_24          -0.117614    -0.145028         -0.122790
# pctnohs18_24        -0.083482    -0.092584         -0.096243
# pctsomecol18_24      0.088527     0.103780          0.093203
# pctbachdeg18_24      0.186542     0.224268          0.209481
# pcths25_over        -0.254249    -0.263704         -0.254167
# pctbachdeg25_over    0.223135     0.245992          0.235851
#
#                    actincidencerate  actdeathrate  pcths18_24  pctnohs18_24  \
# popest2015                -0.042474     -0.208970   -0.117614     -0.083482
# avganncount                0.121902     -0.162996   -0.145028     -0.092584
# avgdeathsperyear          -0.050832     -0.193882   -0.122790     -0.096243
# actincidencerate           1.000000      0.274760    0.019697      0.011833
# actdeathrate               0.274760      1.000000    0.256985      0.125699
# pcths18_24                 0.019697      0.256985    1.000000      0.105305
# pctnohs18_24               0.011833      0.125699    0.105305      1.000000
# pctsomecol18_24           -0.021681     -0.229045   -0.769433     -0.633953
# pctbachdeg18_24           -0.009354     -0.205776   -0.400017     -0.438108
# pcths25_over               0.028643      0.487745    0.412983      0.222100
# pctbachdeg25_over         -0.001447     -0.448336   -0.393350     -0.426075
#
#                    pctsomecol18_24  pctbachdeg18_24  pcths25_over  \
# popest2015                0.088527         0.186542     -0.254249
# avganncount               0.103780         0.224268     -0.263704
# avgdeathsperyear          0.093203         0.209481     -0.254167
# actincidencerate         -0.021681        -0.009354      0.028643
# actdeathrate             -0.229045        -0.205776      0.487745
# pcths18_24               -0.769433        -0.400017      0.412983
# pctnohs18_24             -0.633953        -0.438108      0.222100
# pctsomecol18_24           1.000000         0.269736     -0.375850
# pctbachdeg18_24           0.269736         1.000000     -0.347623
# pcths25_over             -0.375850        -0.347623      1.000000
# pctbachdeg25_over         0.413167         0.586699     -0.747416
#
#                    pctbachdeg25_over
# popest2015                  0.223135
# avganncount                 0.245992
# avgdeathsperyear            0.235851
# actincidencerate           -0.001447
# actdeathrate               -0.448336
# pcths18_24                 -0.393350
# pctnohs18_24               -0.426075
# pctsomecol18_24             0.413167
# pctbachdeg18_24             0.586699
# pcths25_over               -0.747416
# pctbachdeg25_over           1.000000

# %% [markdown]
# ## Q: Is there a relationship between cancer incidence and death rates AND educational level?
# 1. The average number of cancer cases have an extremely weak negative correlation with higher education.  For example, the 3 columns "Some College 18-24 %", "Bachelor Degree 18-24 %" and "Bachelor Degree 25 and Over %" all show a negative correlation to cancer incidence rate, though they are extremely weak correlations.
#
# 1. The average number of deaths has a moderate negative correlation (-0.448336) with "Bachelor Degree 25 and Over %" and a moderate positive correlation (0.487745) with "High School 25 and Over %".
# ### Conclusions:
# * Populations that have a greater percentage of people over 25 with a Bachelor's degree will see lower percentage of cancer deaths.  The reverse is also moderately true. Populations that have a greater percentage of people over 25 with only a high school degree will see higher percentage of cancer deaths.

# %%
# Check out the linear regression between Bachelor's Degree for ages 25 and over and the death rate
x_values = df_combined['pctbachdeg25_over']
y_values = df_combined['actdeathrate']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightgreen", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="blue")
plt.xlabel('% of Bachelors Degree in people aged 25 and over')
plt.ylabel('% of deaths')
plt.show()

# %%
# Check out the linear regression between High School for ages 25 and over and the death rate
x_values = df_combined['pcths25_over']
y_values = df_combined['actdeathrate']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="magenta", edgecolors="black")
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15)
plt.xlabel('% of High School in people aged 25 and over')
plt.ylabel('% of deaths')
plt.show()

# %%
df_combined.head()
# Out:
#                                    statefips  countyfips  avghouseholdsize  \
# geography
# Haines Borough, Alaska                     2         100              2.12
# Kenai Peninsula Borough, Alaska            2         122              2.57
# Ketchikan Gateway Borough, Alaska          2         130              2.55
# Yukon-Koyukuk Census Area, Alaska          2         290              2.81
# Cherokee County, Alabama                   1          19              2.28
#
#                                      state  avganncount  avgdeathsperyear  \
# geography
# Haines Borough, Alaska              Alaska         13.0               4.0
# Kenai Peninsula Borough, Alaska     Alaska        266.0              96.0
# Ketchikan Gateway Borough, Alaska   Alaska         63.0              25.0
# Yukon-Koyukuk Census Area, Alaska   Alaska         27.0              11.0
# Cherokee County, Alabama           Alabama        158.0              69.0
#
#                                    target_deathrate  incidencerate  medincome  \
# geography
# Haines Borough, Alaska                        126.3          413.3    67260.0
# Kenai Peninsula Borough, Alaska               168.1          441.4    62532.0
# Ketchikan Gateway Borough, Alaska             205.0          477.3    57776.0
# Yukon-Koyukuk Census Area, Alaska             206.6          475.1    36708.0
# Cherokee County, Alabama                      191.2          432.6    38013.0
#
#                                    popest2015  ...  pctpubliccoverage  \
# geography                                      ...
# Haines Borough, Alaska                 2534.0  ...               24.4
# Kenai Peninsula Borough, Alaska       58059.0  ...               29.2
# Ketchikan Gateway Borough, Alaska     13709.0  ...               28.3
# Yukon-Koyukuk Census Area, Alaska      5533.0  ...               36.6
# Cherokee County, Alabama              25859.0  ...               43.3
#
#                                    pctpubliccoveragealone   pctwhite  \
# geography
# Haines Borough, Alaska                                9.3  80.546875
# Kenai Peninsula Borough, Alaska                      14.5  84.086262
# Ketchikan Gateway Borough, Alaska                    14.4  67.742171
# Yukon-Koyukuk Census Area, Alaska                    25.4  23.245925
# Cherokee County, Alabama                             20.3  92.921409
#
#                                    pctblack  pctasian  pctotherrace  \
# geography
# Haines Borough, Alaska             0.039062  3.007812      0.507812
# Kenai Peninsula Borough, Alaska    0.634382  1.279251      0.559235
# Ketchikan Gateway Borough, Alaska  0.423389  7.307103      0.656982
# Yukon-Koyukuk Census Area, Alaska  0.301205  0.460666      0.212615
# Cherokee County, Alabama           4.925408  0.338357      0.065365
#
#                                    pctmarriedhouseholds  birthrate  \
# geography
# Haines Borough, Alaska                        47.789116   5.374280
# Kenai Peninsula Borough, Alaska               51.021643   5.680094
# Ketchikan Gateway Borough, Alaska             46.667932   4.936668
# Yukon-Koyukuk Census Area, Alaska             36.377397   6.744604
# Cherokee County, Alabama                      57.173258   4.687790
#
#                                    actdeathrate  actincidencerate
# geography
# Haines Borough, Alaska               157.853197        513.022889
# Kenai Peninsula Borough, Alaska      165.349041        458.154636
# Ketchikan Gateway Borough, Alaska    182.361952        459.552119
# Yukon-Koyukuk Census Area, Alaska    198.807157        487.981204
# Cherokee County, Alabama             266.831664        611.005839
#
# [5 rows x 38 columns]

# %%
df_groupbystate = df_combined.groupby(['state'])

# %%
df_groupbystate['actdeathrate'].mean().sort_values()
# Out:
# state
# Idaho             157.869546
# Utah              160.843761
# California        169.340524
# Arizona           170.690608
# Alaska            176.092837
# Georgia           186.676296
# Colorado          188.664533
# New Mexico        193.826252
# Connecticut       208.035184
# Texas             209.546332
# New Jersey        209.730330
# Vermont           209.854637
# Massachusetts     211.045169
# Oklahoma          213.210150
# Maryland          213.667027
# Michigan          213.723707
# South Carolina    216.337351
# New Hampshire     216.556397
# Wisconsin         217.604524
# Montana           218.913955
# Delaware          221.721808
# Oregon            222.625057
# New York          222.856765
# Illinois          224.925811
# Indiana           225.235481
# North Carolina    226.257021
# Florida           230.606884
# Pennsylvania      232.319814
# Louisiana         233.016019
# Wyoming           233.169808
# Virginia          233.170276
# Iowa              235.958053
# Minnesota         239.058490
# Ohio              245.835760
# Kentucky          246.696526
# Nebraska          246.968509
# West Virginia     247.470148
# Washington        247.915434
# Mississippi       248.003717
# Alabama           249.765919
# Missouri          251.043647
# Maine             257.807926
# Arkansas          263.627248
# Kansas            264.240991
# North Dakota      265.943205
# Tennessee         268.410279
# South Dakota      269.110054
# Nevada            282.432915
# Name: actdeathrate, dtype: float64

# %%
df_groupbystate['actincidencerate'].mean().sort_values()
# Out:
# state
# Arizona             384.121755
# California          445.639901
# New Mexico          449.303016
# Utah                451.853162
# Idaho               466.713144
# Texas               470.130423
# Alaska              479.677712
# Colorado            480.557628
# Georgia             483.565148
# South Carolina      501.101538
# Michigan            514.317447
# Oklahoma            515.692865
# Florida             522.164290
# Indiana             526.487608
# Wisconsin           538.922350
# Maryland            544.257282
# Missouri            547.166808
# Massachusetts       548.150876
# Louisiana           551.915816
# North Carolina      555.590641
# Oregon              564.161050
# Virginia            564.750262
# Mississippi         565.214728
# West Virginia       565.745156
# Montana             566.147916
# Arkansas            567.014553
# Washington          572.979502
# Ohio                573.285781
# Connecticut         584.197238
# Vermont             585.204395
# Alabama             586.285645
# Illinois            586.827900
# Kentucky            592.863173
# New Jersey          604.862387
# Delaware            606.382757
# Iowa                608.423320
# Pennsylvania        609.782346
# Tennessee           612.140425
# New Hampshire       615.241325
# New York            626.113445
# Wyoming             632.499106
# Nebraska            635.043202
# North Dakota        649.907732
# Maine               663.772744
# South Dakota        690.532711
# Minnesota         17473.619031
# Kansas            36954.395092
# Nevada            84137.344808
# Name: actincidencerate, dtype: float64
